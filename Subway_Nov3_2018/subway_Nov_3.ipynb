# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('turnstile_181103.csv')

# %%
df.columns
# Out:
# Index([u'C/A', u'UNIT', u'SCP', u'STATION', u'LINENAME', u'DIVISION', u'DATE',
#        u'TIME', u'DESC', u'ENTRIES',
#        u'EXITS                                                               '],
#       dtype='object')

# %%
df.shape
# Out:
# (199613, 11)

# %%
df.columns = ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
       'DESC', 'ENTRIES','EXITS']

# %%
df.dtypes
# Out:
# C/A         object
# UNIT        object
# SCP         object
# STATION     object
# LINENAME    object
# DIVISION    object
# DATE        object
# TIME        object
# DESC        object
# ENTRIES      int64
# EXITS        int64
# dtype: object

# %%
df.head(3)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/27/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/27/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/27/2018  08:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6811988  2309879
# 1  REGULAR  6812018  2309884
# 2  REGULAR  6812047  2309925

# %%
df['STATION'].nunique()
# Out:
# 375

# %%
df.groupby('STATION').head(3)
# Out:
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 0        A002  R051  02-00-00            59 ST       NQR456W      BMT
# 1        A002  R051  02-00-00            59 ST       NQR456W      BMT
# 2        A002  R051  02-00-00            59 ST       NQR456W      BMT
# 504      A006  R079  00-00-00       5 AV/59 ST          NQRW      BMT
# 505      A006  R079  00-00-00       5 AV/59 ST          NQRW      BMT
# 506      A006  R079  00-00-00       5 AV/59 ST          NQRW      BMT
# 1092     A010  R080  00-00-00       57 ST-7 AV          NQRW      BMT
# 1093     A010  R080  00-00-00       57 ST-7 AV          NQRW      BMT
# 1094     A010  R080  00-00-00       57 ST-7 AV          NQRW      BMT
# 1688     A013  R081  01-00-00            49 ST          NQRW      BMT
# 1689     A013  R081  01-00-00            49 ST          NQRW      BMT
# 1690     A013  R081  01-00-00            49 ST          NQRW      BMT
# ...

# %%
#df.groupby('STATION','DATE').head(3)
df.groupby(['STATION','DATE']).head(3)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/27/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/27/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/27/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/28/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/28/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/28/2018
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT  10/29/2018
# 13       A002  R051  02-00-00          59 ST  NQR456W      BMT  10/29/2018
# 14       A002  R051  02-00-00          59 ST  NQR456W      BMT  10/29/2018
# 18       A002  R051  02-00-00          59 ST  NQR456W      BMT  10/30/2018
# 19       A002  R051  02-00-00          59 ST  NQR456W      BMT  10/30/2018
# ...

# %%
df.groupby('STATION').ENTRIES.mean()
# Out:
# STATION
# 1 AV               2.943030e+08
# 103 ST             1.040552e+07
# 103 ST-CORONA      7.539405e+06
# 104 ST             5.386850e+08
# 110 ST             6.002100e+06
# 111 ST             7.776417e+06
# 116 ST             7.772158e+07
# 116 ST-COLUMBIA    2.037396e+08
# 121 ST             1.842008e+06
# 125 ST             8.630946e+07
# 135 ST             1.093199e+07
# 137 ST CITY COL    2.494109e+07
# 138/GRAND CONC     3.330133e+08
# 14 ST              1.067304e+08
# 14 ST-UNION SQ     2.172456e+07
# 145 ST             5.784174e+07
# 149/GRAND CONC     2.420248e+07
# 14TH STREET        3.804744e+05
# 15 ST-PROSPECT     1.136448e+07
# 155 ST             4.614131e+06
# 157 ST             5.007078e+06
# 161/YANKEE STAD    8.566904e+07
# 163 ST-AMSTERDM    2.311713e+06
# 167 ST             9.117111e+06
# 168 ST             7.501097e+06
# 169 ST             1.882049e+06
# 170 ST             8.748161e+07
# 174 ST             1.192994e+08
# 175 ST             2.389049e+07
# ...

# %%
df.columns
# Out:
# Index([u'C/A', u'UNIT', u'SCP', u'STATION', u'LINENAME', u'DIVISION', u'DATE',
#        u'TIME', u'DESC', u'ENTRIES', u'EXITS'],
#       dtype='object')

# %%
df.groupby('STATION').EXITS.mean()
# Out:
# STATION
# 1 AV               1.594457e+08
# 103 ST             4.160314e+07
# 103 ST-CORONA      7.682643e+06
# 104 ST             3.920633e+08
# 110 ST             5.778059e+06
# 111 ST             4.191393e+06
# 116 ST             9.400955e+07
# 116 ST-COLUMBIA    4.374330e+07
# 121 ST             1.438763e+06
# 125 ST             4.651141e+07
# 135 ST             2.067978e+06
# 137 ST CITY COL    8.767919e+07
# 138/GRAND CONC     3.215198e+08
# 14 ST              7.545686e+07
# 14 ST-UNION SQ     8.003000e+06
# 145 ST             1.228436e+08
# 149/GRAND CONC     3.503494e+06
# 14TH STREET        1.659947e+05
# 15 ST-PROSPECT     5.936056e+05
# 155 ST             3.438353e+06
# 157 ST             3.159820e+06
# 161/YANKEE STAD    4.859656e+07
# 163 ST-AMSTERDM    1.232728e+06
# 167 ST             7.110613e+06
# 168 ST             3.609950e+06
# 169 ST             1.211692e+06
# 170 ST             1.045617e+08
# 174 ST             5.343592e+07
# 175 ST             1.931563e+07
# ...

# %%
df.groupby(['STATION','DATE']).EXITS.mean()
# Out:
# STATION          DATE
# 1 AV             10/27/2018    1.628217e+08
#                  10/28/2018    1.628217e+08
#                  10/29/2018    1.479520e+08
#                  10/30/2018    1.628246e+08
#                  10/31/2018    1.571074e+08
#                  11/01/2018    1.628293e+08
#                  11/02/2018    1.628316e+08
# 103 ST           10/27/2018    4.008166e+07
#                  10/28/2018    4.047069e+07
#                  10/29/2018    4.008363e+07
#                  10/30/2018    4.008510e+07
#                  10/31/2018    4.053206e+07
#                  11/01/2018    4.323475e+07
#                  11/02/2018    4.601287e+07
# 103 ST-CORONA    10/27/2018    7.678533e+06
#                  10/28/2018    7.679662e+06
#                  10/29/2018    7.680784e+06
#                  10/30/2018    7.682393e+06
#                  10/31/2018    7.684047e+06
#                  11/01/2018    7.685706e+06
#                  11/02/2018    7.687379e+06
# ...

# %%
df['EE_Ratio'] = df['ENTRIES']/df['EXITS']

# %%
df.head(3)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/27/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/27/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  10/27/2018  08:00:00
#
#       DESC  ENTRIES    EXITS  EE_Ratio
# 0  REGULAR  6811988  2309879  2.949067
# 1  REGULAR  6812018  2309884  2.949074
# 2  REGULAR  6812047  2309925  2.949034

# %%
df_columbia = df[df.STATION=='116 ST-COLUMBIA']

# %%
type(df_columbia)
# Out:
# pandas.core.frame.DataFrame

# %%
df_columbia.head(3)
# Out:
#          C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 141115  R173  R159  00-00-00  116 ST-COLUMBIA        1      IRT  10/27/2018
# 141116  R173  R159  00-00-00  116 ST-COLUMBIA        1      IRT  10/27/2018
# 141117  R173  R159  00-00-00  116 ST-COLUMBIA        1      IRT  10/27/2018
#
#             TIME     DESC  ENTRIES    EXITS  EE_Ratio
# 141115  01:00:00  REGULAR  4880957  5421760  0.900253
# 141116  05:00:00  REGULAR  4880982  5421824  0.900247
# 141117  09:00:00  REGULAR  4881024  5421979  0.900229

# %%
df_columbia.shape
# Out:
# (252, 12)

# %%
df_columbia.dtypes
# Out:
# C/A          object
# UNIT         object
# SCP          object
# STATION      object
# LINENAME     object
# DIVISION     object
# DATE         object
# TIME         object
# DESC         object
# ENTRIES       int64
# EXITS         int64
# EE_Ratio    float64
# dtype: object

# %%
plt.plot(df_columbia['TIME'], df_columbia['EE_Ratio'])

# %%
plt.plot(df_columbia['TIME'], df_columbia['ENTRIES'])

# %%
df_columbia.groupby('TIME').ENTRIES.value_counts().plot.barh()

# %%
sns.distplot(df_columbia['ENTRIES'])

# %%
sns.distplot(df_columbia['EXITS'])

# %%
sns.distplot(df_columbia['EE_Ratio'])

# %%
df_columbia.describe()
# Out:
#             ENTRIES         EXITS    EE_Ratio
# count  2.520000e+02  2.520000e+02  252.000000
# mean   2.037396e+08  4.374330e+07    2.866965
# std    4.283196e+08  8.587450e+07    1.409880
# min    4.880957e+06  2.522512e+06    0.899893
# 25%    8.464511e+06  5.430575e+06    1.793887
# 50%    1.270127e+07  5.681294e+06    2.702187
# 75%    2.418495e+07  7.790818e+06    4.176475
# max    1.159503e+09  2.353540e+08    4.926643
