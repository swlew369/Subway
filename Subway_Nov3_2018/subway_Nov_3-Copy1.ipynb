# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d = 181229
dflist = [181222,181215,181208, 181201, 181124,181117]

# %%
df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_'+str(d)+'.txt')

for d in dflist:
    df_new = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_'+str(d)+'.txt')
    df = pd.concat([df,df_new])

# %%
df.shape
# Out:
# (1401105, 11)

# %%
#df = pd.read_csv('turnstile_181103.csv')
#df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_'+str(d)+'.txt')

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.columns = ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
       'DESC', 'ENTRIES','EXITS']

# %%
df.dtypes
# Out:
# C/A         object
# UNIT        object
# SCP         object
# STATION     object
# LINENAME    object
# DIVISION    object
# DATE        object
# TIME        object
# DESC        object
# ENTRIES      int64
# EXITS        int64
# dtype: object

# %%
df.head(3)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/22/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/22/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/22/2018  11:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6881995  2333630
# 1  REGULAR  6882006  2333643
# 2  REGULAR  6882062  2333740

# %%
df['STATION'].nunique()
# Out:
# 377

# %%
df.groupby('STATION').head(3)
# Out:
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 0        A002  R051  02-00-00            59 ST       NQR456W      BMT
# 1        A002  R051  02-00-00            59 ST       NQR456W      BMT
# 2        A002  R051  02-00-00            59 ST       NQR456W      BMT
# 504      A006  R079  00-00-00       5 AV/59 ST          NQRW      BMT
# 505      A006  R079  00-00-00       5 AV/59 ST          NQRW      BMT
# 506      A006  R079  00-00-00       5 AV/59 ST          NQRW      BMT
# 1100     A010  R080  00-00-00       57 ST-7 AV          NQRW      BMT
# 1101     A010  R080  00-00-00       57 ST-7 AV          NQRW      BMT
# 1102     A010  R080  00-00-00       57 ST-7 AV          NQRW      BMT
# 1690     A013  R081  01-00-00            49 ST          NQRW      BMT
# 1691     A013  R081  01-00-00            49 ST          NQRW      BMT
# 1692     A013  R081  01-00-00            49 ST          NQRW      BMT
# ...

# %%
#df.groupby('STATION','DATE').head(3)
df.groupby(['STATION','DATE']).head(3)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/22/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/22/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/22/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/23/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/23/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/23/2018
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT  12/24/2018
# 13       A002  R051  02-00-00          59 ST  NQR456W      BMT  12/24/2018
# 14       A002  R051  02-00-00          59 ST  NQR456W      BMT  12/24/2018
# 18       A002  R051  02-00-00          59 ST  NQR456W      BMT  12/25/2018
# 19       A002  R051  02-00-00          59 ST  NQR456W      BMT  12/25/2018
# ...

# %%
df.groupby('STATION').ENTRIES.mean()
# Out:
# STATION
# 1 AV               3.041629e+08
# 103 ST             1.045375e+07
# 103 ST-CORONA      7.617098e+06
# 104 ST             5.352100e+08
# 110 ST             6.039903e+06
# 111 ST             7.807155e+06
# 116 ST             8.222878e+07
# 116 ST-COLUMBIA    2.038177e+08
# 121 ST             1.176147e+08
# 125 ST             8.856409e+07
# 135 ST             1.090539e+07
# 137 ST CITY COL    2.510434e+07
# 138/GRAND CONC     3.330449e+08
# 14 ST              1.143744e+08
# 14 ST-UNION SQ     2.174820e+07
# 145 ST             4.991540e+07
# 149/GRAND CONC     3.172782e+07
# 14TH STREET        3.606907e+05
# 15 ST-PROSPECT     1.143071e+07
# 155 ST             4.636599e+06
# 157 ST             5.044288e+06
# 161/YANKEE STAD    5.732638e+07
# 163 ST-AMSTERDM    2.325911e+06
# 167 ST             9.197830e+06
# 168 ST             7.432698e+06
# 169 ST             1.887389e+06
# 170 ST             8.294034e+07
# 174 ST             1.187017e+08
# 174-175 STS        2.109334e+06
# ...

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
df.groupby('STATION').EXITS.mean()
# Out:
# STATION
# 1 AV               1.629392e+08
# 103 ST             4.058605e+07
# 103 ST-CORONA      7.737579e+06
# 104 ST             3.886944e+08
# 110 ST             5.828021e+06
# 111 ST             4.178979e+06
# 116 ST             1.040372e+08
# 116 ST-COLUMBIA    4.378295e+07
# 121 ST             3.232789e+07
# 125 ST             5.023673e+07
# 135 ST             2.084540e+06
# 137 ST CITY COL    8.843532e+07
# 138/GRAND CONC     3.215476e+08
# 14 ST              8.054032e+07
# 14 ST-UNION SQ     8.014325e+06
# 145 ST             1.047965e+08
# 149/GRAND CONC     1.453856e+06
# 14TH STREET        1.903950e+05
# 15 ST-PROSPECT     6.035457e+05
# 155 ST             3.448118e+06
# 157 ST             3.174478e+06
# 161/YANKEE STAD    3.710631e+07
# 163 ST-AMSTERDM    1.246344e+06
# 167 ST             7.196646e+06
# 168 ST             3.662230e+06
# 169 ST             1.226191e+06
# 170 ST             1.014029e+08
# 174 ST             5.321003e+07
# 174-175 STS        9.683288e+05
# ...

# %%
df.groupby(['STATION','DATE']).EXITS.mean()
# Out:
# STATION    DATE
# 1 AV       11/10/2018    1.628469e+08
#            11/11/2018    1.628469e+08
#            11/12/2018    1.628477e+08
#            11/13/2018    1.628497e+08
#            11/14/2018    1.628520e+08
#            11/15/2018    1.628544e+08
#            11/16/2018    1.628569e+08
#            11/17/2018    1.628582e+08
#            11/18/2018    1.628582e+08
#            11/19/2018    1.628592e+08
#            11/20/2018    1.571410e+08
#            11/21/2018    1.628635e+08
#            11/22/2018    1.628650e+08
#            11/23/2018    1.628661e+08
#            11/24/2018    1.628673e+08
#            11/25/2018    1.628685e+08
#            11/26/2018    1.696308e+08
#            11/27/2018    1.628724e+08
#            11/28/2018    1.628746e+08
#            11/29/2018    1.628770e+08
#            11/30/2018    1.628794e+08
#            12/01/2018    1.628816e+08
#            12/02/2018    1.628832e+08
#            12/03/2018    1.628850e+08
# ...
